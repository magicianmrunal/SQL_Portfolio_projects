# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\Hp\Downloads\Ice Cream Ratings.csv")
df
# Out:
#        Date  Flavor Rating  Texture Rating  Overall Rating
# 0  1/1/2022       0.223090        0.040220        0.600129
# 1  1/2/2022       0.635886        0.938476        0.106264
# 2  1/3/2022       0.442323        0.044154        0.598112
# 3  1/4/2022       0.389128        0.549676        0.489353
# 4  1/5/2022       0.386887        0.519439        0.988280
# 5  1/6/2022       0.877984        0.193588        0.832827
# 6  1/7/2022       0.140995        0.325110        0.105147

# %%
df.set_index('Date',inplace=True)

# %%
plt.style.available
plt.style.use('ggplot')

# %%
df.plot(kind='line',title='Ice Cream Ratings',xlabel='Date',ylabel='Ratings')
#df.plot(subplots=True)
# Out:
# <Axes: title={'center': 'Ice Cream Ratings'}, xlabel='Date', ylabel='Ratings'>

# %%
df.plot(kind='bar',stacked=True)
#df['Flavor Rating'].plot(kind='bar',stacked=True)
df.plot.barh(stacked=True)
# Out:
# <Axes: ylabel='Date'>

# %%
df.plot.scatter(x='Texture Rating',y='Overall Rating',s=100,c='green')
# Out:
# <Axes: xlabel='Texture Rating', ylabel='Overall Rating'>

# %%
df.plot.hist(bins = 30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
df.plot.area(figsize=(10,3))
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot.pie(y='Flavor Rating',figsize=(10,7))
# Out:
# <Axes: ylabel='Flavor Rating'>
